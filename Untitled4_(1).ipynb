# %%
# !pip install tensorflow numpy matplotlib seaborn gradio --quiet

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gradio as gr
from sklearn.manifold import TSNE
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_style('whitegrid')

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
def preprocess_data(X_train, X_test):

    X_train = X_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
    X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
    return X_train, X_test

X_train, X_test = preprocess_data(X_train, X_test)

# %%
def create_improved_model():
    model = keras.Sequential([
        keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D((2, 2)),

        keras.layers.Conv2D(64, (3, 3), activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.MaxPooling2D((2, 2)),

        keras.layers.Conv2D(128, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.4),

        keras.layers.Flatten(),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

model = create_improved_model()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 11, 11, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3, 3, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 3, 3, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 391,050 (1.49 MB)
#  Trainable params: 390,730 (1.49 MB)
#  Non-trainable params: 320 (1.25 KB)

# %%
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=3),
    keras.callbacks.ModelCheckpoint('best_model.h5', save_best_only=True)
]

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=128),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7421 - loss: 0.8423
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 63ms/step - accuracy: 0.7426 - loss: 0.8405 - val_accuracy: 0.7315 - val_loss: 0.6859 - learning_rate: 0.0010
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9523 - loss: 0.1572
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9523 - loss: 0.1572 - val_accuracy: 0.9844 - val_loss: 0.0486 - learning_rate: 0.0010
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9646 - loss: 0.1159
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.9646 - loss: 0.1159 - val_accuracy: 0.9898 - val_loss: 0.0318 - learning_rate: 0.0010
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 42ms/step - accuracy: 0.9720 - loss: 0.0931 - val_accuracy: 0.9879 - val_loss: 0.0414 - learning_rate: 0.0010
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.9752 - loss: 0.0843 - val_accuracy: 0.9879 - val_loss: 0.0436 - learning_rate: 0.0010
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9769 - loss: 0.0781
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9769 - loss: 0.0781 - val_accuracy: 0.9915 - val_loss: 0.0272 - learning_rate: 0.0010
# Epoch 7/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9789 - loss: 0.0728
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9789 - loss: 0.0728 - val_accuracy: 0.9917 - val_loss: 0.0249 - learning_rate: 0.0010
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 40ms/step - accuracy: 0.9789 - loss: 0.0702 - val_accuracy: 0.9914 - val_loss: 0.0313 - learning_rate: 0.0010
# Epoch 9/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9811 - loss: 0.0670
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 37ms/step - accuracy: 0.9811 - loss: 0.0670 - val_accuracy: 0.9933 - val_loss: 0.0195 - learning_rate: 0.0010
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9821 - loss: 0.0619 - val_accuracy: 0.9910 - val_loss: 0.0273 - learning_rate: 0.0010
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.9822 - loss: 0.0603 - val_accuracy: 0.9913 - val_loss: 0.0247 - learning_rate: 0.0010
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.9833 - loss: 0.0564 - val_accuracy: 0.9899 - val_loss: 0.0314 - learning_rate: 0.0010
# Epoch 13/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9849 - loss: 0.0532
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9849 - loss: 0.0532 - val_accuracy: 0.9948 - val_loss: 0.0158 - learning_rate: 1.0000e-04
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9879 - loss: 0.0417 - val_accuracy: 0.9952 - val_loss: 0.0159 - learning_rate: 1.0000e-04
# Epoch 15/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9888 - loss: 0.0422
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9888 - loss: 0.0422 - val_accuracy: 0.9958 - val_loss: 0.0144 - learning_rate: 1.0000e-04
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9883 - loss: 0.0408 - val_accuracy: 0.9954 - val_loss: 0.0148 - learning_rate: 1.0000e-04
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.9890 - loss: 0.0375 - val_accuracy: 0.9952 - val_loss: 0.0151 - learning_rate: 1.0000e-04
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9882 - loss: 0.0429
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9882 - loss: 0.0429 - val_accuracy: 0.9958 - val_loss: 0.0139 - learning_rate: 1.0000e-04
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.9881 - loss: 0.0406 - val_accuracy: 0.9955 - val_loss: 0.0146 - learning_rate: 1.0000e-04
# Epoch 20/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9906 - loss: 0.0344
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9906 - loss: 0.0344 - val_accuracy: 0.9955 - val_loss: 0.0138 - learning_rate: 1.0000e-04
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9900 - loss: 0.0350 - val_accuracy: 0.9950 - val_loss: 0.0150 - learning_rate: 1.0000e-04
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 37ms/step - accuracy: 0.9898 - loss: 0.0354 - val_accuracy: 0.9955 - val_loss: 0.0143 - learning_rate: 1.0000e-04
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9905 - loss: 0.0327
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9905 - loss: 0.0327 - val_accuracy: 0.9955 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 24/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9900 - loss: 0.0351
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9900 - loss: 0.0351 - val_accuracy: 0.9955 - val_loss: 0.0134 - learning_rate: 1.0000e-04
# Epoch 25/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9906 - loss: 0.0328 - val_accuracy: 0.9951 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 26/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9910 - loss: 0.0309
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.9910 - loss: 0.0309 - val_accuracy: 0.9956 - val_loss: 0.0132 - learning_rate: 1.0000e-04
# Epoch 27/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9907 - loss: 0.0319 - val_accuracy: 0.9957 - val_loss: 0.0141 - learning_rate: 1.0000e-04
# Epoch 28/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9912 - loss: 0.0309 - val_accuracy: 0.9956 - val_loss: 0.0133 - learning_rate: 1.0000e-04
# Epoch 29/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.9906 - loss: 0.0306 - val_accuracy: 0.9948 - val_loss: 0.0143 - learning_rate: 1.0000e-04
# Epoch 30/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9919 - loss: 0.0288 - val_accuracy: 0.9955 - val_loss: 0.0133 - learning_rate: 1.0000e-05
# Epoch 31/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 36ms/step - accuracy: 0.9900 - loss: 0.0333 - val_accuracy: 0.9959 - val_loss: 0.0133 - learning_rate: 1.0000e-05

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=128),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9907 - loss: 0.0305
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 31s 66ms/step - accuracy: 0.9907 - loss: 0.0305 - val_accuracy: 0.9957 - val_loss: 0.0130 - learning_rate: 1.0000e-05
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 37ms/step - accuracy: 0.9914 - loss: 0.0306 - val_accuracy: 0.9959 - val_loss: 0.0130 - learning_rate: 1.0000e-05
# Epoch 3/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9909 - loss: 0.0308
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9909 - loss: 0.0308 - val_accuracy: 0.9961 - val_loss: 0.0128 - learning_rate: 1.0000e-05
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 42ms/step - accuracy: 0.9914 - loss: 0.0283 - val_accuracy: 0.9957 - val_loss: 0.0130 - learning_rate: 1.0000e-05
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 36ms/step - accuracy: 0.9907 - loss: 0.0319 - val_accuracy: 0.9957 - val_loss: 0.0131 - learning_rate: 1.0000e-05
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 39ms/step - accuracy: 0.9921 - loss: 0.0287 - val_accuracy: 0.9959 - val_loss: 0.0130 - learning_rate: 1.0000e-05
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 17s 36ms/step - accuracy: 0.9916 - loss: 0.0288 - val_accuracy: 0.9958 - val_loss: 0.0131 - learning_rate: 1.0000e-06
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 38ms/step - accuracy: 0.9907 - loss: 0.0313 - val_accuracy: 0.9958 - val_loss: 0.0130 - learning_rate: 1.0000e-06

# %%
model = keras.models.load_model('best_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nТочность на тестовых данных: {test_acc:.4f}")
# Out:
# Точность на тестовых данных: 0.9961

# %%
def plot_training_history(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Точность (обучение)')
    plt.plot(history.history['val_accuracy'], label='Точность (валидация)')
    plt.title('Точность модели')
    plt.ylabel('Точность')
    plt.xlabel('Эпоха')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Потери (обучение)')
    plt.plot(history.history['val_loss'], label='Потери (валидация)')
    plt.title('Потери модели')
    plt.ylabel('Потери')
    plt.xlabel('Эпоха')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %%
def plot_confusion_matrix():
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)

    cm = tf.math.confusion_matrix(y_test, y_pred_labels)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Предсказанные')
    plt.ylabel('Истинные')
    plt.title('Матрица ошибок')
    plt.show()

plot_confusion_matrix()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
def visualize_filters():
    first_layer_weights = model.layers[0].get_weights()[0]

    plt.figure(figsize=(12, 6))
    for i in range(16):
        plt.subplot(4, 4, i+1)
        plt.imshow(first_layer_weights[:, :, 0, i], cmap='viridis')
        plt.axis('off')
    plt.suptitle('Фильтры первого сверточного слоя')
    plt.show()

visualize_filters()

# %%
def visualize_tsne():
    feature_extractor = keras.Model(
        inputs=model.inputs,
        outputs=model.layers[-3].output
    )

    features = feature_extractor.predict(X_test[:1000])
    tsne = TSNE(n_components=2, random_state=42)
    features_2d = tsne.fit_transform(features)

    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], c=y_test[:1000],
                         cmap='tab10', alpha=0.6)
    plt.legend(*scatter.legend_elements(), title='Цифры')
    plt.title('t-SNE визуализация признаков')
    plt.show()

visualize_tsne()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_3']
# Received: inputs=Tensor(shape=(32, 28, 28, 1))
#   warnings.warn(msg)
#  1/32 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_3']
# Received: inputs=Tensor(shape=(None, 28, 28, 1))
#   warnings.warn(msg)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step

# %%
def predict_image(img):
    img = img.reshape(1, 28, 28, 1).astype('float32') / 255
    pred = model.predict(img)
    return {str(i): float(pred[0][i]) for i in range(10)}

interface = gr.Interface(
    predict_image,
    gr.Image(height=28, width=28, image_mode='L'),
    gr.Label(num_top_classes=3),
    title="Распознавание рукописных цифр",
    description="Загрузите изображение цифры (28x28 пикселей)"
)

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('mnist_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("\nМодель успешно сохранена в формате TFLite!")
# Out:
# Saved artifact at '/tmp/tmpkj6gxq3c'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='input_layer_3')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   133898826183120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826184848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826185424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826185616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826182928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826186576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133898826186384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711021136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711033232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711033424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711031888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711021520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899711036112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899763832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899763835600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899763831184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133899763828688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# Модель успешно сохранена в формате TFLite!

# %%
print("\nЗапуск Gradio интерфейса...")
interface.launch(share=True)
# Out:
# Запуск Gradio интерфейса...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c3f9948e427df815df.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c3f9948e427df815df.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from google.colab import files
files.download('best_model.h5')  # Скачать .h5
files.download('mnist_model.tflite')  # Скачать .tflite
