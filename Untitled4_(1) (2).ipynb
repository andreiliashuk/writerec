# %%
# !pip install tensorflow numpy matplotlib seaborn gradio --quiet

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gradio as gr
from sklearn.manifold import TSNE
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
plt.rcParams['figure.figsize'] = (12, 8)
sns.set_style('whitegrid')

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
def preprocess_data(X_train, X_test):

    X_train = X_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
    X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
    return X_train, X_test

X_train, X_test = preprocess_data(X_train, X_test)

# %%
def create_improved_model():
    model = keras.Sequential([
        keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
        keras.layers.BatchNormalization(),
        keras.layers.MaxPooling2D((2, 2)),

        keras.layers.Conv2D(64, (3, 3), activation='relu'),
        keras.layers.Dropout(0.3),
        keras.layers.MaxPooling2D((2, 2)),

        keras.layers.Conv2D(128, (3, 3), activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Dropout(0.4),

        keras.layers.Flatten(),
        keras.layers.Dense(256, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    return model

model = create_improved_model()
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 26, 26, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ...

# %%
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=3),
    keras.callbacks.ModelCheckpoint('best_model.h5', save_best_only=True)
]

# %%
print("Форма X_train:", X_train.shape)
print("Тип данных X_train:", X_train.dtype)
print("Максимум в X_train:", X_train.max())
print("Минимум в X_train:", X_train.min())


unique_classes, counts = np.unique(y_train, return_counts=True)
print("\nРаспределение классов в y_train:")
for cls, count in zip(unique_classes, counts):
    print(f"Цифра {cls}: {count} образцов")


plt.figure(figsize=(12, 2))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_train[i].squeeze(), cmap="gray")
    plt.title(f"Метка: {y_train[i]}")
    plt.axis("off")
plt.suptitle("Примеры обучающих изображений")
plt.show()
# Out:
# Форма X_train: (60000, 28, 28, 1)
# Тип данных X_train: float32
# Максимум в X_train: 1.0
# Минимум в X_train: 0.0
#
# Распределение классов в y_train:
# Цифра 0: 5923 образцов
# Цифра 1: 6742 образцов
# Цифра 2: 5958 образцов
# Цифра 3: 6131 образцов
# Цифра 4: 5842 образцов
# Цифра 5: 5421 образцов
# Цифра 6: 5918 образцов
# Цифра 7: 6265 образцов
# Цифра 8: 5851 образцов
# Цифра 9: 5949 образцов

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=128),
    epochs=50,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7543 - loss: 0.8224
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 71ms/step - accuracy: 0.7545 - loss: 0.8215 - val_accuracy: 0.6353 - val_loss: 0.8684 - learning_rate: 0.0010
# Epoch 2/50
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9520 - loss: 0.1570
# ...

# %%
model = keras.models.load_model('best_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"\nТочность на тестовых данных: {test_acc:.4f}")
# Out:
# Точность на тестовых данных: 0.9946

# %%
def plot_training_history(history):
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Точность (обучение)')
    plt.plot(history.history['val_accuracy'], label='Точность (валидация)')
    plt.title('Точность модели')
    plt.ylabel('Точность')
    plt.xlabel('Эпоха')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Потери (обучение)')
    plt.plot(history.history['val_loss'], label='Потери (валидация)')
    plt.title('Потери модели')
    plt.ylabel('Потери')
    plt.xlabel('Эпоха')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %%
def plot_confusion_matrix():
    y_pred = model.predict(X_test)
    y_pred_labels = np.argmax(y_pred, axis=1)

    cm = tf.math.confusion_matrix(y_test, y_pred_labels)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Предсказанные')
    plt.ylabel('Истинные')
    plt.title('Матрица ошибок')
    plt.show()

plot_confusion_matrix()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
def visualize_filters():
    first_layer_weights = model.layers[0].get_weights()[0]

    plt.figure(figsize=(12, 6))
    for i in range(16):
        plt.subplot(4, 4, i+1)
        plt.imshow(first_layer_weights[:, :, 0, i], cmap='viridis')
        plt.axis('off')
    plt.suptitle('Фильтры первого сверточного слоя')
    plt.show()

visualize_filters()

# %%
def visualize_tsne():
    feature_extractor = keras.Model(
        inputs=model.inputs,
        outputs=model.layers[-3].output
    )

    features = feature_extractor.predict(X_test[:1000])
    tsne = TSNE(n_components=2, random_state=42)
    features_2d = tsne.fit_transform(features)

    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(features_2d[:, 0], features_2d[:, 1], c=y_test[:1000],
                         cmap='tab10', alpha=0.6)
    plt.legend(*scatter.legend_elements(), title='Цифры')
    plt.title('t-SNE визуализация признаков')
    plt.show()

visualize_tsne()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_1']
# Received: inputs=Tensor(shape=(32, 28, 28, 1))
#   warnings.warn(msg)
# 27/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_1']
# Received: inputs=Tensor(shape=(None, 28, 28, 1))
#   warnings.warn(msg)
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step

# %%
import cv2
def predict_image(img):
    try:
        if img.shape != (28, 28):
            img = cv2.resize(img, (28, 28))
        img = img.reshape(1, 28, 28, 1).astype('float32') / 255
        pred = model.predict(img)
        return {str(i): float(pred[0][i]) for i in range(10)}
    except Exception as e:
        return {"error": str(e)}
interface = gr.Interface(
    predict_image,
    gr.Image(height=28, width=28, image_mode='L'),
    gr.Label(num_top_classes=3),
    title="Распознавание рукописных цифр",
    description="Загрузите изображение цифры (28x28 пикселей)"
)

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('mnist_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("\nМодель успешно сохранена в формате TFLite!")
# Out:
# Saved artifact at '/tmp/tmpujrevzpb'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28, 28, 1), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   139960308293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308301456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308293584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308299920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308293776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308299536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308300304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308292432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139960308299728: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
print("\nЗапуск Gradio интерфейса...")
interface.launch(share=True)
# Out:
# Запуск Gradio интерфейса...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://2ed339a9e80aa93c1a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://2ed339a9e80aa93c1a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from google.colab import files
files.download('best_model.h5')  # Скачать .h5
files.download('mnist_model.tflite')  # Скачать .tflite
